# %% [markdown]
# https://www.sap-tcodes.org/download/sheet/

# %%
import numpy as np
import pandas as pd

# %%
sap = pd.read_csv("SAP-TCodes_Name_MM-EN.csv")
sap
# Out:
#    TCODE                           TCODE_DESC  \
# 0   MM00                              (empty)
# 1   MM01                    Create Material &
# 2   MM02                    Change Material &
# 3   MM03                   Display Material &
# 4   MM04    Display Material Change Documents
# ..   ...                                  ...
# 84  MMVV  Change Centr. for Decentr. Shipping
# 85  MMW1          Create Competitor Product &
# 86  MMZ1  Create Material, General (Old MM01)
# 87  MMZ2           Change Material (Old MM02)
# 88  MMZ3          Display Material (Old MM03)
#
#                                      TCODE_URL ABAP_PROGRAM PACKAGE  \
# 0   https://www.sap-tcodes.org/tcode/mm00.html     MENUMM00      MG
# 1   https://www.sap-tcodes.org/tcode/mm01.html     SAPMMG01      MG
# 2   https://www.sap-tcodes.org/tcode/mm02.html     SAPMMG01      MG
# 3   https://www.sap-tcodes.org/tcode/mm03.html     SAPMMG01      MG
# ...

# %%
cod = sap[sap["TCODE"] == "MM60"]

# %%
cod
# Out:
#    TCODE      TCODE_DESC                                   TCODE_URL  \
# 21  MM60  Materials List  https://www.sap-tcodes.org/tcode/mm60.html
#
#    ABAP_PROGRAM PACKAGE                                       PACKAGE_DESC  \
# 21     RMMVRZ00      MG  Application development R/3 material master pr...
#
#    MODULE                       MODULE_DESC  \
# 21    CRM  Customer Relationship Management
#
#                                            MODULE_URL MODULE_TOP  \
# 21  https://www.sap-tcodes.org/analytics/module/cr...        CRM
#
#                      MODULE_TOP_DESC  \
# 21  Customer Relationship Management
#
#                                        MODULE_TOP_URL COMPONENT  \
# 21  https://www.sap-tcodes.org/analytics/module/cr...    BBPCRM
#
#    COMPONENT_DESC                                      COMPONENT_URL
# 21         BBPCRM  https://www.sap-tcodes.org/analytics/component...
